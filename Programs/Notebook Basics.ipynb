# %%
print("Hello World")

# %%
# %sql
Select "Hello world form sql!"

# %% [markdown]
# #Title
# ##Title

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
print(full_name)

# %%
display(
  dbutils.fs.ls('/databricks-datasets/')
)

# %%
dbutils.fs.help()
dbutils.fs.help('cp')
dbutils.fs.cp('dbfs:/databricks-datasets/', '', True)
